# %%
from pymongo import MongoClient
import pandas as pd

# %%
client=MongoClient('mongodb+srv://nguyenthanhdatpy:01259229215dat@warehouse.favm3s8.mongodb.net/?retryWrites=true&w=majority')

# %%
db=client.hourly_game_data

# %%
collection=db.detail

# %%
cursor=collection.find({})
document=cursor[0]
document.pop('_id')
data=list(document.values())[0]
for i in data:
    i['datetime']=list(document.keys())[0]
data
# Out:
# [{'rank': '1',
#   'name': 'Counter-Strike 2',
#   'price': 'Free To Play',
#   'current_player': '600,991',
#   'peak_player': '1,122,355',
#   'link': 'https://store.steampowered.com/app/730/CounterStrike_2?snr=1_7001_7005__7003',
#   'genre': ['Action, Free to Play'],
#   'description': 'For over two decades, Counter-Strike has offered an elite competitive experience, one shaped by millions of players from across the globe. And now the next chapter in the CS story is about to begin. This is Counter-Strike 2.',
#   'feature_list': ['Cross-Platform Multiplayer',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Remote Play on Phone',
#    'Remote Play on Tablet',
#    'Remote Play on TV'],
#   'supported_languages': ['English',
#    'Czech',
#    'Danish',
#    'Dutch',
#    'Finnish',
#    'French',
#    'German',
#    'Hungarian',
#    'Italian',
#    'Japanese',
#    'Korean',
#    'Norwegian',
# ...

# %%
cursor=collection.find({})
data={}
dfs=[]
for document in cursor:
    document.pop('_id')
    data=list(document.values())[0]
    for i in data:
        i['datetime']=list(document.keys())[0]
    dfs.append(pd.DataFrame(data))

# %%
dfs[0]
# Out:
#                                   26-10-2023_08-16-22
# 0   {'rank': '1', 'name': 'Counter-Strike 2', 'pri...
# 1   {'rank': '2', 'name': 'Dota 2', 'price': 'Free...
# 2   {'rank': '3', 'name': 'PUBG: BATTLEGROUNDS', '...
# 3   {'rank': '4', 'name': 'Apex Legends™', 'price'...
# 4   {'rank': '5', 'name': 'NARAKA: BLADEPOINT', 'p...
# ..                                                ...
# 92  {'rank': '96', 'name': 'Soundpad', 'price': '$...
# 93  {'rank': '97', 'name': 'Blender', 'price': 'Fr...
# 94  {'rank': '98', 'name': 'MONSTER HUNTER RISE', ...
# 95  {'rank': '99', 'name': 'Melvor Idle', 'price':...
# 96  {'rank': '100', 'name': 'Albion Online', 'pric...
#
# [97 rows x 1 columns]

# %%
merged_df = pd.concat(dfs, ignore_index=True)
merged_df
# Out:
#       rank                  name         price current_player peak_player  \
# 0        1      Counter-Strike 2  Free To Play        600,991   1,122,355
# 1        2                Dota 2  Free To Play        321,601     663,939
# 2        3   PUBG: BATTLEGROUNDS  Free To Play        204,275     425,714
# 3        4         Apex Legends™  Free To Play        147,097     364,565
# 4        5    NARAKA: BLADEPOINT  Free To Play        110,314     265,814
# ...    ...                   ...           ...            ...         ...
# 52313   96          Satisfactory        $29.99          9,098      10,491
# 52314   97        Counter-Strike         $9.99          9,030      13,073
# 52315   98  MY HERO ULTRA RUMBLE  Free To Play          8,755      12,699
# 52316   99         Halo Infinite  Free To Play          8,637      14,531
# 52317  100         Albion Online  Free To Play          8,590      12,633
#
#                                                     link  \
# ...
